# %% [markdown]
# # 라이브러리 확인

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import urllib3
urllib3.disable_warnings()


#tfds.disable_progress_bar()   # 이 주석을 풀면 데이터셋 다운로드과정의 프로그레스바가 나타나지 않습니다.
setattr(
    tfds.image_classification.cats_vs_dogs,
    '_URL',
    'https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip')

(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
# 데이터의 개수도 확인해 봅시다.
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
def normalize_and_resize_img(image, label):
    
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, [224, 224])
    return tf.cast(image, tf.float32) / 255., label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %%
ds_info.features["label"].num_classes
# Out:
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']

# %% [markdown]
# # resnet block

# %%
# is_50 : True --> resnet_50
# is_plain :True --> no skip connection    
def build_resnet_block(input_layer, num_cnn=3, channel=64, block_num=1,is_50 = False,is_plain = False):
    # 입력 레이어
    x = input_layer
    if not is_50:
    # CNN 레이어
        for cnn_num in range(num_cnn):
            identity = x
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}'
            )(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_1_conv{cnn_num}'
            )(x)
            if not is_plain:
                identity_channel = identity.shape.as_list()[-1]    

                if identity_channel != channel:
                    identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)  
                # skip connection
                x = keras.layers.Add()([x,identity])   
            else:
                pass
    else :
        identity = x
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(1,1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_conv{cnn_num}'
        )(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(3,3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_1_conv{cnn_num}'
        )(x)
        x = keras.layers.Conv2D(
            filters=channel * 4,
            kernel_size=(1,1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_2_conv{cnn_num}'
        )(x)
        if not is_plain:
            identity_channel = identity.shape.as_list()[-1]    

            if identity_channel != channel:
                identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)  
            # skip connection
            x = keras.layers.Add()([x,identity])   
        else:
            pass
    #     Max Pooling 레이어
    # 마지막 블록 뒤에는 pooling을 하지 않음
    if identity.shape[1] != 1:        
        x = keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            strides=2,
            name=f'block{block_num}_pooling'
        )(x)

    return x

# %% [markdown]
# 기본 값은 resnet-34로 되어있고 두가지 옵션이 있는데 이는 각각 이것을 의미한다.
#
# is_50 : resnet 50을 사용할지 안할지를 정하는 bool 변수
#
# is_plain : skip connection을 사용할지 안할지를 정하는 bool 변수이다.

# %% [markdown]
# # resnet builder

# %%
def build_resnet(input_shape=(224,224,3),
              num_cnn_list=[3,4,6,3],
              channel_list=[64,128,256,512],
              num_classes=10,is_50 = False, is_plain = False):
    
    assert len(num_cnn_list) == len(channel_list) #모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    if is_50:
        num_cnn_list = [3,4,6,3]
        channel_list = [64,128,256,512]
        num_classes = 10
        
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer
    #conv1층
    output = keras.layers.Conv2D(filters=64,
                       kernel_size = (2,2),
                       strides = 2,
                         padding = 'valid')(output)
    output = keras.layers.BatchNormalization()(output)
    
    #conv2_x pooling
    output = keras.layers.MaxPooling2D(pool_size = (2,2),
                                      strides = 2,)(output)    
    # config list들의 길이만큼 반복해서 블록을 생성합니다.
    for i, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        output = build_resnet_block(
            output,
            num_cnn=num_cnn, 
            channel=channel,
            block_num=i
        )    
    output = keras.layers.AveragePooling2D(padding = 'same')(output)
    output = keras.layers.Flatten(name='flatten')(output)
    output = keras.layers.Dense(512, activation='relu', name='fc1')(output)    
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
resnet_34 = build_resnet(is_50 = False)
resnet_50 = build_resnet(is_50 = True)
plain_resnet_34 = build_resnet(is_50 = False, is_plain = True)
plain_resnet_50 = build_resnet(is_50 = True, is_plain = True)

# %%
resnet_34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  832         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['block0_conv0[0][0]']
#  rmalization)
#
#  block0_1_conv0 (Conv2D)        (None, 56, 56, 64)   36928       ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 56, 56, 64)   0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 56, 56, 64)   36928       ['add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['block0_conv1[0][0]']
#  rmalization)
#
#  block0_1_conv1 (Conv2D)        (None, 56, 56, 64)   36928       ['batch_normalization_2[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 64)   0           ['block0_1_conv1[0][0]',
#                                                                   'add[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 56, 56, 64)   36928       ['add_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 64)  256         ['block0_conv2[0][0]']
#  rmalization)
#
#  block0_1_conv2 (Conv2D)        (None, 56, 56, 64)   36928       ['batch_normalization_3[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 64)   0           ['block0_1_conv2[0][0]',
#                                                                   'add_1[0][0]']
#
#  block0_pooling (MaxPooling2D)  (None, 28, 28, 64)   0           ['add_2[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 28, 28, 128)  73856       ['block0_pooling[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 128)  512        ['block1_conv0[0][0]']
#  rmalization)
#
#  block1_1_conv0 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_4[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 128)  8320        ['block0_pooling[0][0]']
#
#  add_3 (Add)                    (None, 28, 28, 128)  0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 28, 28, 128)  147584      ['add_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 128)  512        ['block1_conv1[0][0]']
#  rmalization)
#
#  block1_1_conv1 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_5[0][0]']
#
#  add_4 (Add)                    (None, 28, 28, 128)  0           ['block1_1_conv1[0][0]',
#                                                                   'add_3[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 28, 28, 128)  147584      ['add_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 128)  512        ['block1_conv2[0][0]']
#  rmalization)
#
#  block1_1_conv2 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_6[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 128)  0           ['block1_1_conv2[0][0]',
#                                                                   'add_4[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 28, 28, 128)  147584      ['add_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 128)  512        ['block1_conv3[0][0]']
#  rmalization)
#
#  block1_1_conv3 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_7[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['block1_1_conv3[0][0]',
#                                                                   'add_5[0][0]']
#
#  block1_pooling (MaxPooling2D)  (None, 14, 14, 128)  0           ['add_6[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 14, 14, 256)  295168      ['block1_pooling[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 256)  1024       ['block2_conv0[0][0]']
#  rmalization)
#
#  block2_1_conv0 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_8[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 256)  33024       ['block1_pooling[0][0]']
#
#  add_7 (Add)                    (None, 14, 14, 256)  0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 14, 14, 256)  590080      ['add_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 14, 14, 256)  1024       ['block2_conv1[0][0]']
#  rmalization)
#
#  block2_1_conv1 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_9[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['block2_1_conv1[0][0]',
#                                                                   'add_7[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 14, 14, 256)  590080      ['add_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_10[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['block2_1_conv2[0][0]',
#                                                                   'add_8[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 14, 14, 256)  590080      ['add_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_11[0][0]']
#
#  add_10 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv3[0][0]',
#                                                                   'add_9[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 14, 14, 256)  590080      ['add_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_12[0][0]']
#
#  add_11 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv4[0][0]',
#                                                                   'add_10[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 14, 14, 256)  590080      ['add_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_13[0][0]']
#
#  add_12 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv5[0][0]',
#                                                                   'add_11[0][0]']
#
#  block2_pooling (MaxPooling2D)  (None, 7, 7, 256)    0           ['add_12[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 7, 7, 512)    1180160     ['block2_pooling[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 512)   2048        ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 7, 7, 512)    2359808     ['batch_normalization_14[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 512)    131584      ['block2_pooling[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 512)    0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 7, 7, 512)    2359808     ['add_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 7, 7, 512)   2048        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 7, 7, 512)    2359808     ['batch_normalization_15[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 512)    0           ['block3_1_conv1[0][0]',
#                                                                   'add_13[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 7, 7, 512)    2359808     ['add_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 512)   2048        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 7, 7, 512)    2359808     ['batch_normalization_16[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 512)    0           ['block3_1_conv2[0][0]',
#                                                                   'add_14[0][0]']
#
#  block3_pooling (MaxPooling2D)  (None, 3, 3, 512)    0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 2, 2, 512)   0           ['block3_pooling[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 512)          1049088     ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 22,337,098
# Trainable params: 22,329,418
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
resnet_50.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 112, 112, 64  832         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 112, 112, 64  256        ['conv2d_4[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['batch_normalization_17[0][0]']
#
#  block0_conv0 (Conv2D)          (None, 56, 56, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 56, 56, 64)  256         ['block0_conv0[0][0]']
#  ormalization)
#
#  block0_1_conv0 (Conv2D)        (None, 56, 56, 64)   36928       ['batch_normalization_18[0][0]']
#
#  add_16 (Add)                   (None, 56, 56, 64)   0           ['block0_1_conv0[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  block0_conv1 (Conv2D)          (None, 56, 56, 64)   36928       ['add_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 56, 56, 64)  256         ['block0_conv1[0][0]']
#  ormalization)
#
#  block0_1_conv1 (Conv2D)        (None, 56, 56, 64)   36928       ['batch_normalization_19[0][0]']
#
#  add_17 (Add)                   (None, 56, 56, 64)   0           ['block0_1_conv1[0][0]',
#                                                                   'add_16[0][0]']
#
#  block0_conv2 (Conv2D)          (None, 56, 56, 64)   36928       ['add_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 56, 56, 64)  256         ['block0_conv2[0][0]']
#  ormalization)
#
#  block0_1_conv2 (Conv2D)        (None, 56, 56, 64)   36928       ['batch_normalization_20[0][0]']
#
#  add_18 (Add)                   (None, 56, 56, 64)   0           ['block0_1_conv2[0][0]',
#                                                                   'add_17[0][0]']
#
#  block0_pooling (MaxPooling2D)  (None, 28, 28, 64)   0           ['add_18[0][0]']
#
#  block1_conv0 (Conv2D)          (None, 28, 28, 128)  73856       ['block0_pooling[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['block1_conv0[0][0]']
#  ormalization)
#
#  block1_1_conv0 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_21[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  8320        ['block0_pooling[0][0]']
#
#  add_19 (Add)                   (None, 28, 28, 128)  0           ['block1_1_conv0[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  block1_conv1 (Conv2D)          (None, 28, 28, 128)  147584      ['add_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['block1_conv1[0][0]']
#  ormalization)
#
#  block1_1_conv1 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_22[0][0]']
#
#  add_20 (Add)                   (None, 28, 28, 128)  0           ['block1_1_conv1[0][0]',
#                                                                   'add_19[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 28, 28, 128)  147584      ['add_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 128)  512        ['block1_conv2[0][0]']
#  ormalization)
#
#  block1_1_conv2 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_23[0][0]']
#
#  add_21 (Add)                   (None, 28, 28, 128)  0           ['block1_1_conv2[0][0]',
#                                                                   'add_20[0][0]']
#
#  block1_conv3 (Conv2D)          (None, 28, 28, 128)  147584      ['add_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 128)  512        ['block1_conv3[0][0]']
#  ormalization)
#
#  block1_1_conv3 (Conv2D)        (None, 28, 28, 128)  147584      ['batch_normalization_24[0][0]']
#
#  add_22 (Add)                   (None, 28, 28, 128)  0           ['block1_1_conv3[0][0]',
#                                                                   'add_21[0][0]']
#
#  block1_pooling (MaxPooling2D)  (None, 14, 14, 128)  0           ['add_22[0][0]']
#
#  block2_conv0 (Conv2D)          (None, 14, 14, 256)  295168      ['block1_pooling[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv0[0][0]']
#  ormalization)
#
#  block2_1_conv0 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_25[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 256)  33024       ['block1_pooling[0][0]']
#
#  add_23 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv0[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 14, 14, 256)  590080      ['add_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv1[0][0]']
#  ormalization)
#
#  block2_1_conv1 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_26[0][0]']
#
#  add_24 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv1[0][0]',
#                                                                   'add_23[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 14, 14, 256)  590080      ['add_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv2[0][0]']
#  ormalization)
#
#  block2_1_conv2 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_27[0][0]']
#
#  add_25 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv2[0][0]',
#                                                                   'add_24[0][0]']
#
#  block2_conv3 (Conv2D)          (None, 14, 14, 256)  590080      ['add_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv3[0][0]']
#  ormalization)
#
#  block2_1_conv3 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_28[0][0]']
#
#  add_26 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv3[0][0]',
#                                                                   'add_25[0][0]']
#
#  block2_conv4 (Conv2D)          (None, 14, 14, 256)  590080      ['add_26[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv4[0][0]']
#  ormalization)
#
#  block2_1_conv4 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_29[0][0]']
#
#  add_27 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv4[0][0]',
#                                                                   'add_26[0][0]']
#
#  block2_conv5 (Conv2D)          (None, 14, 14, 256)  590080      ['add_27[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 256)  1024       ['block2_conv5[0][0]']
#  ormalization)
#
#  block2_1_conv5 (Conv2D)        (None, 14, 14, 256)  590080      ['batch_normalization_30[0][0]']
#
#  add_28 (Add)                   (None, 14, 14, 256)  0           ['block2_1_conv5[0][0]',
#                                                                   'add_27[0][0]']
#
#  block2_pooling (MaxPooling2D)  (None, 7, 7, 256)    0           ['add_28[0][0]']
#
#  block3_conv0 (Conv2D)          (None, 7, 7, 512)    1180160     ['block2_pooling[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 512)   2048        ['block3_conv0[0][0]']
#  ormalization)
#
#  block3_1_conv0 (Conv2D)        (None, 7, 7, 512)    2359808     ['batch_normalization_31[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 512)    131584      ['block2_pooling[0][0]']
#
#  add_29 (Add)                   (None, 7, 7, 512)    0           ['block3_1_conv0[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 7, 7, 512)    2359808     ['add_29[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 512)   2048        ['block3_conv1[0][0]']
#  ormalization)
#
#  block3_1_conv1 (Conv2D)        (None, 7, 7, 512)    2359808     ['batch_normalization_32[0][0]']
#
#  add_30 (Add)                   (None, 7, 7, 512)    0           ['block3_1_conv1[0][0]',
#                                                                   'add_29[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 7, 7, 512)    2359808     ['add_30[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 512)   2048        ['block3_conv2[0][0]']
#  ormalization)
#
#  block3_1_conv2 (Conv2D)        (None, 7, 7, 512)    2359808     ['batch_normalization_33[0][0]']
#
#  add_31 (Add)                   (None, 7, 7, 512)    0           ['block3_1_conv2[0][0]',
#                                                                   'add_30[0][0]']
#
#  block3_pooling (MaxPooling2D)  (None, 3, 3, 512)    0           ['add_31[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 2, 2, 512)   0           ['block3_pooling[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d_1[0][0]']
#
#  fc1 (Dense)                    (None, 512)          1049088     ['flatten[0][0]']
#
#  predictions (Dense)            (None, 10)           5130        ['fc1[0][0]']
#
# ==================================================================================================
# Total params: 22,337,098
# Trainable params: 22,329,418
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 64
EPOCH = 30

# %%
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %% [markdown]
# # 모델 학습
#
# Resnet 모델

# %%
resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

histoty_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 290/290 [==============================] - 88s 226ms/step - loss: 1.5387 - accuracy: 0.5721 - val_loss: 1.6679 - val_accuracy: 0.4749
# Epoch 2/30
# 290/290 [==============================] - 61s 210ms/step - loss: 1.0220 - accuracy: 0.6253 - val_loss: 1.1222 - val_accuracy: 0.5530
# Epoch 3/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.7556 - accuracy: 0.6703 - val_loss: 0.7279 - val_accuracy: 0.6878
# Epoch 4/30
# 290/290 [==============================] - 61s 211ms/step - loss: 0.6172 - accuracy: 0.7025 - val_loss: 0.6693 - val_accuracy: 0.6933
# Epoch 5/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.5078 - accuracy: 0.7540 - val_loss: 0.7036 - val_accuracy: 0.6539
# Epoch 6/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.4522 - accuracy: 0.7867 - val_loss: 0.5252 - val_accuracy: 0.7658
# Epoch 7/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.4098 - accuracy: 0.8107 - val_loss: 0.5338 - val_accuracy: 0.7537
# Epoch 8/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.3655 - accuracy: 0.8356 - val_loss: 0.5354 - val_accuracy: 0.7588
# Epoch 9/30
# 290/290 [==============================] - 61s 211ms/step - loss: 0.3159 - accuracy: 0.8619 - val_loss: 0.5206 - val_accuracy: 0.7847
# Epoch 10/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.2869 - accuracy: 0.8766 - val_loss: 0.6389 - val_accuracy: 0.7513
# Epoch 11/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.2459 - accuracy: 0.8962 - val_loss: 0.5912 - val_accuracy: 0.7694
# Epoch 12/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.1926 - accuracy: 0.9213 - val_loss: 0.5561 - val_accuracy: 0.7975
# Epoch 13/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.1631 - accuracy: 0.9339 - val_loss: 0.5792 - val_accuracy: 0.7938
# Epoch 14/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.1302 - accuracy: 0.9492 - val_loss: 0.5459 - val_accuracy: 0.8113
# Epoch 15/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.1016 - accuracy: 0.9610 - val_loss: 0.9752 - val_accuracy: 0.7611
# Epoch 16/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0834 - accuracy: 0.9681 - val_loss: 0.7611 - val_accuracy: 0.7901
# Epoch 17/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0691 - accuracy: 0.9744 - val_loss: 0.7286 - val_accuracy: 0.8053
# Epoch 18/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0542 - accuracy: 0.9804 - val_loss: 0.7350 - val_accuracy: 0.8086
# Epoch 19/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0445 - accuracy: 0.9844 - val_loss: 0.7537 - val_accuracy: 0.8123
# Epoch 20/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0401 - accuracy: 0.9861 - val_loss: 1.0169 - val_accuracy: 0.7739
# Epoch 21/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0369 - accuracy: 0.9861 - val_loss: 0.8438 - val_accuracy: 0.8129
# Epoch 22/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0290 - accuracy: 0.9898 - val_loss: 0.8781 - val_accuracy: 0.8073
# Epoch 23/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0266 - accuracy: 0.9906 - val_loss: 0.9652 - val_accuracy: 0.8040
# Epoch 24/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.9402 - val_accuracy: 0.8189
# Epoch 25/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.9340 - val_accuracy: 0.8166
# Epoch 26/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 1.0174 - val_accuracy: 0.8021
# Epoch 27/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.8570 - val_accuracy: 0.8190
# Epoch 28/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.9578 - val_accuracy: 0.8210
# Epoch 29/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.9727 - val_accuracy: 0.8241
# Epoch 30/30
# 290/290 [==============================] - 61s 211ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.9449 - val_accuracy: 0.8235

# %%
resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

histoty_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 290/290 [==============================] - 77s 211ms/step - loss: 1.5563 - accuracy: 0.5822 - val_loss: 0.9097 - val_accuracy: 0.5545
# Epoch 2/30
# 290/290 [==============================] - 61s 210ms/step - loss: 1.0329 - accuracy: 0.6325 - val_loss: 0.7891 - val_accuracy: 0.6635
# Epoch 3/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.7512 - accuracy: 0.6820 - val_loss: 0.6974 - val_accuracy: 0.6981
# Epoch 4/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.6218 - accuracy: 0.7108 - val_loss: 0.8710 - val_accuracy: 0.6058
# Epoch 5/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.5188 - accuracy: 0.7517 - val_loss: 0.5502 - val_accuracy: 0.7400
# Epoch 6/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.4750 - accuracy: 0.7750 - val_loss: 0.5118 - val_accuracy: 0.7681
# Epoch 7/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.4244 - accuracy: 0.8018 - val_loss: 0.4853 - val_accuracy: 0.7672
# Epoch 8/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.3900 - accuracy: 0.8218 - val_loss: 0.8324 - val_accuracy: 0.6702
# Epoch 9/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.3395 - accuracy: 0.8499 - val_loss: 0.5136 - val_accuracy: 0.7704
# Epoch 10/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.3006 - accuracy: 0.8695 - val_loss: 0.6580 - val_accuracy: 0.7296
# Epoch 11/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.2560 - accuracy: 0.8936 - val_loss: 0.6044 - val_accuracy: 0.7679
# Epoch 12/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.2223 - accuracy: 0.9075 - val_loss: 0.4685 - val_accuracy: 0.8082
# Epoch 13/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.1744 - accuracy: 0.9308 - val_loss: 0.5192 - val_accuracy: 0.8086
# Epoch 14/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.1414 - accuracy: 0.9446 - val_loss: 0.6394 - val_accuracy: 0.7807
# Epoch 15/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.1138 - accuracy: 0.9573 - val_loss: 0.5923 - val_accuracy: 0.8034
# Epoch 16/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0893 - accuracy: 0.9652 - val_loss: 0.6802 - val_accuracy: 0.7999
# Epoch 17/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0800 - accuracy: 0.9689 - val_loss: 0.9004 - val_accuracy: 0.7695
# Epoch 18/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0593 - accuracy: 0.9788 - val_loss: 0.9202 - val_accuracy: 0.7718
# Epoch 19/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0533 - accuracy: 0.9803 - val_loss: 0.6693 - val_accuracy: 0.8051
# Epoch 20/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0449 - accuracy: 0.9841 - val_loss: 1.0616 - val_accuracy: 0.7663
# Epoch 21/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0371 - accuracy: 0.9868 - val_loss: 1.3630 - val_accuracy: 0.7382
# Epoch 22/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0295 - accuracy: 0.9901 - val_loss: 0.8220 - val_accuracy: 0.8206
# Epoch 23/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0239 - accuracy: 0.9917 - val_loss: 0.7707 - val_accuracy: 0.8118
# Epoch 24/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.8910 - val_accuracy: 0.8118
# Epoch 25/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.8795 - val_accuracy: 0.8167
# Epoch 26/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.8196 - val_accuracy: 0.8190
# Epoch 27/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 1.0504 - val_accuracy: 0.7951
# Epoch 28/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.8551 - val_accuracy: 0.8241
# Epoch 29/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.8906 - val_accuracy: 0.8080
# Epoch 30/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.9525 - val_accuracy: 0.8184

# %% [markdown]
# # plain 모델

# %%
plain_resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

histoty_plain_34 = plain_resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 290/290 [==============================] - 77s 211ms/step - loss: 1.5065 - accuracy: 0.5700 - val_loss: 0.7602 - val_accuracy: 0.5762
# Epoch 2/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.9514 - accuracy: 0.6338 - val_loss: 0.8683 - val_accuracy: 0.5820
# Epoch 3/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.7230 - accuracy: 0.6700 - val_loss: 0.9347 - val_accuracy: 0.5812
# Epoch 4/30
# 290/290 [==============================] - 61s 211ms/step - loss: 0.5832 - accuracy: 0.7158 - val_loss: 0.6273 - val_accuracy: 0.6853
# Epoch 5/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.5124 - accuracy: 0.7529 - val_loss: 0.5610 - val_accuracy: 0.7196
# Epoch 6/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.4573 - accuracy: 0.7852 - val_loss: 0.5501 - val_accuracy: 0.7409
# Epoch 7/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.4146 - accuracy: 0.8084 - val_loss: 0.5389 - val_accuracy: 0.7636
# Epoch 8/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.3672 - accuracy: 0.8341 - val_loss: 0.8693 - val_accuracy: 0.6528
# Epoch 9/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.3276 - accuracy: 0.8527 - val_loss: 0.5124 - val_accuracy: 0.7843
# Epoch 10/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.2814 - accuracy: 0.8788 - val_loss: 0.6424 - val_accuracy: 0.7502
# Epoch 11/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.2432 - accuracy: 0.8984 - val_loss: 0.5880 - val_accuracy: 0.7674
# Epoch 12/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.1981 - accuracy: 0.9187 - val_loss: 0.5419 - val_accuracy: 0.8121
# Epoch 13/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.1606 - accuracy: 0.9362 - val_loss: 0.7574 - val_accuracy: 0.7578
# Epoch 14/30
# 290/290 [==============================] - 61s 209ms/step - loss: 0.1231 - accuracy: 0.9527 - val_loss: 0.6501 - val_accuracy: 0.7862
# Epoch 15/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0968 - accuracy: 0.9632 - val_loss: 0.9271 - val_accuracy: 0.7581
# Epoch 16/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0780 - accuracy: 0.9701 - val_loss: 0.7450 - val_accuracy: 0.7829
# Epoch 17/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0662 - accuracy: 0.9756 - val_loss: 0.6419 - val_accuracy: 0.8139
# Epoch 18/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0535 - accuracy: 0.9809 - val_loss: 0.6532 - val_accuracy: 0.8275
# Epoch 19/30
# 290/290 [==============================] - 61s 210ms/step - loss: 0.0404 - accuracy: 0.9852 - val_loss: 1.5884 - val_accuracy: 0.7003
# Epoch 20/30
# 290/290 [==============================] - 61s 211ms/step - loss: 0.0382 - accuracy: 0.9863 - val_loss: 0.8247 - val_accuracy: 0.7975
# Epoch 21/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0311 - accuracy: 0.9888 - val_loss: 0.8039 - val_accuracy: 0.8082
# Epoch 22/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.8785 - val_accuracy: 0.8030
# Epoch 23/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.7250 - val_accuracy: 0.8289
# Epoch 24/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.7824 - val_accuracy: 0.8211
# Epoch 25/30
# 290/290 [==============================] - 60s 209ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.8031 - val_accuracy: 0.8212
# Epoch 26/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.7778 - val_accuracy: 0.8311
# Epoch 27/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.9168 - val_accuracy: 0.8283
# Epoch 28/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.8200 - val_accuracy: 0.8322
# Epoch 29/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.8302 - val_accuracy: 0.8331
# Epoch 30/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.8450 - val_accuracy: 0.8346

# %%
plain_resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

histoty_plain_50 = plain_resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 290/290 [==============================] - 77s 209ms/step - loss: 1.7399 - accuracy: 0.5711 - val_loss: 0.8392 - val_accuracy: 0.5773
# Epoch 2/30
# 290/290 [==============================] - 60s 208ms/step - loss: 1.1474 - accuracy: 0.6267 - val_loss: 0.9467 - val_accuracy: 0.6233
# Epoch 3/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.8579 - accuracy: 0.6692 - val_loss: 0.7544 - val_accuracy: 0.6814
# Epoch 4/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.6673 - accuracy: 0.7113 - val_loss: 0.9705 - val_accuracy: 0.6609
# Epoch 5/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.5393 - accuracy: 0.7476 - val_loss: 0.6091 - val_accuracy: 0.7265
# Epoch 6/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.4659 - accuracy: 0.7794 - val_loss: 0.6467 - val_accuracy: 0.7007
# Epoch 7/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.4265 - accuracy: 0.7984 - val_loss: 0.4970 - val_accuracy: 0.7842
# Epoch 8/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.3745 - accuracy: 0.8313 - val_loss: 1.0324 - val_accuracy: 0.6393
# Epoch 9/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.3213 - accuracy: 0.8593 - val_loss: 0.4880 - val_accuracy: 0.7877
# Epoch 10/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.2828 - accuracy: 0.8782 - val_loss: 0.7699 - val_accuracy: 0.7194
# Epoch 11/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.2309 - accuracy: 0.9024 - val_loss: 0.8547 - val_accuracy: 0.7097
# Epoch 12/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.1882 - accuracy: 0.9217 - val_loss: 0.8436 - val_accuracy: 0.7190
# Epoch 13/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.1584 - accuracy: 0.9380 - val_loss: 0.9355 - val_accuracy: 0.7143
# Epoch 14/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.1309 - accuracy: 0.9476 - val_loss: 0.6775 - val_accuracy: 0.7888
# Epoch 15/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.1035 - accuracy: 0.9598 - val_loss: 0.8431 - val_accuracy: 0.7690
# Epoch 16/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0855 - accuracy: 0.9666 - val_loss: 0.6827 - val_accuracy: 0.7968
# Epoch 17/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0689 - accuracy: 0.9751 - val_loss: 0.7545 - val_accuracy: 0.7962
# Epoch 18/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0556 - accuracy: 0.9796 - val_loss: 0.7428 - val_accuracy: 0.7875
# Epoch 19/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0451 - accuracy: 0.9836 - val_loss: 0.9394 - val_accuracy: 0.7840
# Epoch 20/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.8120 - val_accuracy: 0.8118
# Epoch 21/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0325 - accuracy: 0.9888 - val_loss: 0.7793 - val_accuracy: 0.8185
# Epoch 22/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0266 - accuracy: 0.9907 - val_loss: 0.7818 - val_accuracy: 0.8193
# Epoch 23/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0229 - accuracy: 0.9927 - val_loss: 1.0514 - val_accuracy: 0.7797
# Epoch 24/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 1.0227 - val_accuracy: 0.7893
# Epoch 25/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 1.0292 - val_accuracy: 0.7966
# Epoch 26/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.8130 - val_accuracy: 0.8158
# Epoch 27/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.8953 - val_accuracy: 0.8213
# Epoch 28/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.9270 - val_accuracy: 0.8144
# Epoch 29/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.8526 - val_accuracy: 0.8256
# Epoch 30/30
# 290/290 [==============================] - 60s 208ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.8951 - val_accuracy: 0.8261

# %% [markdown]
# # 시각화하기
#
# 훈련손실값(training loss)

# %%
import matplotlib.pyplot as plt

plt.plot(histoty_34.history['loss'], 'r')
plt.plot(histoty_50.history['loss'], 'b')

plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'resnet_50'], loc='lower left')
plt.show()

# %%
plt.plot(histoty_plain_34.history['loss'],'g')
plt.plot(histoty_plain_50.history['loss'], 'm')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['plain_34','plain_50'], loc='lower left')
plt.show()

# %% [markdown]
# # 검증 정확도
#
# val_accuracy

# %%
plt.plot(histoty_34.history['val_accuracy'], 'r')
plt.plot(histoty_50.history['val_accuracy'], 'b')

plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['resnet_34', 'resnet_50'], loc='lower right')
plt.show()

# %%
plt.plot(histoty_plain_34.history['val_accuracy'],'g')
plt.plot(histoty_plain_50.history['val_accuracy'], 'm')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['plain_34','plain_50'], loc='lower right')
plt.show()

# %% [markdown]
# # 회고

# %% [markdown]
# 시각화를 통해서 resnet 모델을 적용한 것과 그렇지 않은 것에 대해서 비교를 하였다.
# 에폭을 처음에는 15로 주었는데 plain 모델과 큰 차이를 못 느껴 30으로 수정해서 테스트하였다.
# loss 값은 큰 의미있는 차이를 못 느꼈고, val_accuracy 값에서 resnet 모델을 사용하여 층을 쌓았을때 층이 깊을수록 정확도가 향상되는 것을 볼 수 있었다.
