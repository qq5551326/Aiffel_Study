# %% [markdown]
# # 16-13. 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %%
# 라이브러리 확인
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %% [markdown]
# # 프로젝트 수행
# ***
#
# 프로젝트를 진행하면서 필수로 수행해야 할 사항은 다음과 같습니다.
#
# 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.
#    (어떠한 방법을 사용했는지 적어주세요.)
# 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다.
#    테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %%
# 이미지 개수 확인
import os

data_path = os.getenv('HOME')+'/aiffel/cityscapes/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
#이미지 나누기
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    original = img[:, w:, :] 
    original = tf.cast(original, tf.float32)
    return normalize(sketch), normalize(original)

f = data_path + os.listdir(data_path)[1]
sketch, original = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(original))

# %%
#여러 augmentation 방법 적용

from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, original):
    stacked = tf.concat([sketch, original], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %% [markdown]
# 데이터에 **apply augmentation** 방법을 적용하여 학습했다.
# 스케치 및 채색된 2개 이미지를 입력으로 받아 여러 가지 연산을 두 이미지에 동일하게 적용 하였다.

# %%
#시각화
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_original = apply_augmentation(sketch, original)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_original)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
#적용 확인 시각화
from tensorflow import data

def get_train(img_path):
    sketch, original = load_img(img_path)
    sketch, original = apply_augmentation(sketch, original)
    return sketch, original

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, original = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(original[0].astype(np.uint8))

# %% [markdown]
# # (2) Generator 구성
# 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용했다.

# %%
from tensorflow.keras import layers, Input, Model

# %%
#Encoder 및 Decoder에 사용되는 기본적인 블록
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %%
#정의된 블록들을 이용해 한 번에 U-Net Generator를 정의
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
#U-Net 구조 Generator 내부의 각 출력이 적절한지 확인
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # (4) Discriminator 구성하기

# %%
#Discriminator 기본적인 블록 구현
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
#출력 크기 확인

inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
#Discriminator 만들기

class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
#블록별 출력 크기 확인
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
#출력 시각화
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # (5) 학습 및 테스트

# %%
#손실함수 : Generator 및 Discriminator의 손실 계산 정의
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
#최적화 : 사용할 optimizer 설정
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
#가중치 업데이트 : 하나의 배치 크기만큼 데이터를 입력했을 때 가중치를 1회 업데이트
@tf.function
def train_step(sketch, original):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, original, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, original, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
#학습
EPOCHS = 100

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, original) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, original)
                
        # 20회 반복마다 손실을 출력합니다.
        if (i+1) % 20 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[20]
# Generator_loss:1.2071
# L1_loss:0.3080
# Discriminator_loss:1.0859
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.4717
# L1_loss:0.2693
# Discriminator_loss:0.7725
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.6413
# L1_loss:0.2193
# Discriminator_loss:0.5900
#
# EPOCH[1] - STEP[80]
# Generator_loss:2.0614
# L1_loss:0.2934
# Discriminator_loss:0.5718
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.8763
# L1_loss:0.2544
# Discriminator_loss:0.6890
#
# EPOCH[1] - STEP[120]
# Generator_loss:2.0670
# L1_loss:0.2009
# Discriminator_loss:0.6607
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.5225
# L1_loss:0.2969
# Discriminator_loss:0.6335
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.9012
# L1_loss:0.2250
# Discriminator_loss:1.2552
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.0197
# L1_loss:0.2364
# Discriminator_loss:0.5990
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.6853
# L1_loss:0.2578
# Discriminator_loss:0.4542
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.3500
# L1_loss:0.2470
# Discriminator_loss:0.4721
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.6453
# L1_loss:0.2707
# Discriminator_loss:0.4096
#
# EPOCH[2] - STEP[20]
# Generator_loss:0.9320
# L1_loss:0.2342
# Discriminator_loss:1.6323
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.9925
# L1_loss:0.2373
# Discriminator_loss:0.3821
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.3440
# L1_loss:0.1656
# Discriminator_loss:0.6258
#
# EPOCH[2] - STEP[80]
# Generator_loss:3.2833
# L1_loss:0.2753
# Discriminator_loss:1.1911
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.6974
# L1_loss:0.2005
# Discriminator_loss:0.3947
#
# EPOCH[2] - STEP[120]
# Generator_loss:0.9374
# L1_loss:0.2097
# Discriminator_loss:0.7114
#
# EPOCH[2] - STEP[140]
# Generator_loss:2.3875
# L1_loss:0.2759
# Discriminator_loss:0.2885
#
# EPOCH[2] - STEP[160]
# Generator_loss:2.3794
# L1_loss:0.1817
# Discriminator_loss:0.4969
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.8084
# L1_loss:0.1697
# Discriminator_loss:0.5840
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.3088
# L1_loss:0.2226
# Discriminator_loss:0.3232
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.5537
# L1_loss:0.2141
# Discriminator_loss:0.9090
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.8557
# L1_loss:0.2221
# Discriminator_loss:0.3461
#
# EPOCH[3] - STEP[20]
# Generator_loss:3.0088
# L1_loss:0.2024
# Discriminator_loss:0.6240
#
# EPOCH[3] - STEP[40]
# Generator_loss:2.7290
# L1_loss:0.2090
# Discriminator_loss:0.7057
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.2364
# L1_loss:0.1904
# Discriminator_loss:0.5897
#
# EPOCH[3] - STEP[80]
# Generator_loss:0.5555
# L1_loss:0.2002
# Discriminator_loss:1.3587
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.3497
# L1_loss:0.2134
# Discriminator_loss:0.7181
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.0450
# L1_loss:0.1976
# Discriminator_loss:0.5850
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.8763
# L1_loss:0.2221
# Discriminator_loss:1.0917
#
# EPOCH[3] - STEP[160]
# Generator_loss:0.8322
# L1_loss:0.2593
# Discriminator_loss:0.7798
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.7783
# L1_loss:0.1992
# Discriminator_loss:0.1895
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.4329
# L1_loss:0.2227
# Discriminator_loss:0.5109
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.6839
# L1_loss:0.2112
# Discriminator_loss:0.5674
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.7906
# L1_loss:0.1736
# Discriminator_loss:0.8548
#
# EPOCH[4] - STEP[20]
# Generator_loss:0.7503
# L1_loss:0.1727
# Discriminator_loss:1.0018
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.4663
# L1_loss:0.1705
# Discriminator_loss:0.6150
#
# EPOCH[4] - STEP[60]
# Generator_loss:2.6835
# L1_loss:0.1930
# Discriminator_loss:1.2731
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.3970
# L1_loss:0.2136
# Discriminator_loss:0.7044
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.4467
# L1_loss:0.2003
# Discriminator_loss:0.5232
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.8734
# L1_loss:0.2088
# Discriminator_loss:0.4519
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.0751
# L1_loss:0.1982
# Discriminator_loss:0.5443
#
# EPOCH[4] - STEP[160]
# Generator_loss:3.2760
# L1_loss:0.1767
# Discriminator_loss:2.2704
#
# EPOCH[4] - STEP[180]
# Generator_loss:2.1247
# L1_loss:0.2090
# Discriminator_loss:0.2891
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6836
# L1_loss:0.1528
# Discriminator_loss:0.6357
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.2972
# L1_loss:0.2087
# Discriminator_loss:0.4766
#
# EPOCH[4] - STEP[240]
# Generator_loss:2.0612
# L1_loss:0.1910
# Discriminator_loss:0.6051
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.5078
# L1_loss:0.2402
# Discriminator_loss:1.5440
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.9544
# L1_loss:0.1926
# Discriminator_loss:0.5548
#
# EPOCH[5] - STEP[60]
# Generator_loss:0.9254
# L1_loss:0.1673
# Discriminator_loss:1.2798
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.4117
# L1_loss:0.2108
# Discriminator_loss:0.7077
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.4849
# L1_loss:0.1756
# Discriminator_loss:0.8235
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.5076
# L1_loss:0.1763
# Discriminator_loss:0.5322
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.8696
# L1_loss:0.1801
# Discriminator_loss:0.7445
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.7071
# L1_loss:0.1911
# Discriminator_loss:0.9238
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.0222
# L1_loss:0.1708
# Discriminator_loss:1.0026
#
# EPOCH[5] - STEP[200]
# Generator_loss:0.8127
# L1_loss:0.1811
# Discriminator_loss:0.7486
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.3007
# L1_loss:0.2041
# Discriminator_loss:1.1584
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.2117
# L1_loss:0.1726
# Discriminator_loss:0.7450
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.2646
# L1_loss:0.1516
# Discriminator_loss:0.6373
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.8991
# L1_loss:0.1827
# Discriminator_loss:1.0353
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.8687
# L1_loss:0.1648
# Discriminator_loss:0.9912
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.3267
# L1_loss:0.1910
# Discriminator_loss:0.7849
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.0101
# L1_loss:0.1783
# Discriminator_loss:1.2777
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.7798
# L1_loss:0.1548
# Discriminator_loss:0.5944
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.9354
# L1_loss:0.1626
# Discriminator_loss:0.4537
#
# EPOCH[6] - STEP[160]
# Generator_loss:2.3748
# L1_loss:0.1718
# Discriminator_loss:1.6224
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.6895
# L1_loss:0.1736
# Discriminator_loss:0.9404
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.2811
# L1_loss:0.1620
# Discriminator_loss:1.8412
#
# EPOCH[6] - STEP[220]
# Generator_loss:2.4793
# L1_loss:0.2173
# Discriminator_loss:0.1992
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.8408
# L1_loss:0.1829
# Discriminator_loss:0.5028
#
# EPOCH[7] - STEP[20]
# Generator_loss:0.8733
# L1_loss:0.1647
# Discriminator_loss:0.8320
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.2582
# L1_loss:0.1821
# Discriminator_loss:1.3018
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.2824
# L1_loss:0.2254
# Discriminator_loss:0.5082
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.7783
# L1_loss:0.1518
# Discriminator_loss:0.3426
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.3027
# L1_loss:0.2488
# Discriminator_loss:0.4408
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.9957
# L1_loss:0.2241
# Discriminator_loss:0.3772
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.9576
# L1_loss:0.1929
# Discriminator_loss:0.7069
#
# EPOCH[7] - STEP[160]
# Generator_loss:2.2909
# L1_loss:0.2032
# Discriminator_loss:0.4284
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.3986
# L1_loss:0.1808
# Discriminator_loss:0.4832
#
# EPOCH[7] - STEP[200]
# Generator_loss:0.6991
# L1_loss:0.1754
# Discriminator_loss:1.0320
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.3540
# L1_loss:0.1714
# Discriminator_loss:1.5988
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.4579
# L1_loss:0.1906
# Discriminator_loss:0.4339
#
# EPOCH[8] - STEP[20]
# Generator_loss:2.6393
# L1_loss:0.2106
# Discriminator_loss:0.6978
#
# EPOCH[8] - STEP[40]
# Generator_loss:3.6101
# L1_loss:0.1758
# Discriminator_loss:0.5118
#
# EPOCH[8] - STEP[60]
# Generator_loss:0.8303
# L1_loss:0.2166
# Discriminator_loss:0.9420
#
# EPOCH[8] - STEP[80]
# Generator_loss:3.0488
# L1_loss:0.1652
# Discriminator_loss:0.3000
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.5499
# L1_loss:0.1638
# Discriminator_loss:0.3643
#
# EPOCH[8] - STEP[120]
# Generator_loss:0.9549
# L1_loss:0.1892
# Discriminator_loss:0.9778
#
# EPOCH[8] - STEP[140]
# Generator_loss:2.2923
# L1_loss:0.1530
# Discriminator_loss:1.2466
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.6318
# L1_loss:0.1987
# Discriminator_loss:0.3363
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.6545
# L1_loss:0.1803
# Discriminator_loss:0.6705
#
# EPOCH[8] - STEP[200]
# Generator_loss:0.6764
# L1_loss:0.2133
# Discriminator_loss:1.0520
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.4736
# L1_loss:0.1754
# Discriminator_loss:0.6089
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.2878
# L1_loss:0.1685
# Discriminator_loss:1.5332
#
# EPOCH[9] - STEP[20]
# Generator_loss:0.8245
# L1_loss:0.1775
# Discriminator_loss:0.8537
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.1073
# L1_loss:0.1937
# Discriminator_loss:0.7179
#
# EPOCH[9] - STEP[60]
# Generator_loss:0.9955
# L1_loss:0.1989
# Discriminator_loss:0.7555
#
# EPOCH[9] - STEP[80]
# Generator_loss:3.6285
# L1_loss:0.1766
# Discriminator_loss:0.3520
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.2291
# L1_loss:0.1799
# Discriminator_loss:0.5300
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.8643
# L1_loss:0.2351
# Discriminator_loss:0.4431
#
# EPOCH[9] - STEP[140]
# Generator_loss:0.6469
# L1_loss:0.2234
# Discriminator_loss:0.9210
#
# EPOCH[9] - STEP[160]
# Generator_loss:2.6122
# L1_loss:0.1592
# Discriminator_loss:0.4233
#
# EPOCH[9] - STEP[180]
# Generator_loss:2.5547
# L1_loss:0.2155
# Discriminator_loss:0.9153
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.3027
# L1_loss:0.1355
# Discriminator_loss:0.9610
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.3728
# L1_loss:0.1797
# Discriminator_loss:0.5078
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.3429
# L1_loss:0.2072
# Discriminator_loss:0.4499
#
# EPOCH[10] - STEP[20]
# Generator_loss:2.0826
# L1_loss:0.1718
# Discriminator_loss:1.2078
#
# EPOCH[10] - STEP[40]
# Generator_loss:2.7588
# L1_loss:0.1899
# Discriminator_loss:0.7658
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.4607
# L1_loss:0.1883
# Discriminator_loss:0.6719
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.8931
# L1_loss:0.1593
# Discriminator_loss:0.7881
#
# EPOCH[10] - STEP[100]
# Generator_loss:1.3339
# L1_loss:0.1640
# Discriminator_loss:0.6856
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.8512
# L1_loss:0.1880
# Discriminator_loss:0.6329
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.4746
# L1_loss:0.2369
# Discriminator_loss:0.4781
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.9368
# L1_loss:0.1929
# Discriminator_loss:0.3987
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.5597
# L1_loss:0.2044
# Discriminator_loss:0.9071
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.4045
# L1_loss:0.2103
# Discriminator_loss:0.5911
#
# EPOCH[10] - STEP[220]
# Generator_loss:2.6548
# L1_loss:0.2052
# Discriminator_loss:0.4238
#
# EPOCH[10] - STEP[240]
# Generator_loss:2.2423
# L1_loss:0.1568
# Discriminator_loss:0.9190
#
# EPOCH[11] - STEP[20]
# Generator_loss:2.2464
# L1_loss:0.1495
# Discriminator_loss:0.3207
#
# EPOCH[11] - STEP[40]
# Generator_loss:2.8514
# L1_loss:0.2328
# Discriminator_loss:0.1762
#
# EPOCH[11] - STEP[60]
# Generator_loss:2.4932
# L1_loss:0.1855
# Discriminator_loss:0.1655
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.6477
# L1_loss:0.1973
# Discriminator_loss:0.2987
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.7998
# L1_loss:0.1836
# Discriminator_loss:0.3910
#
# EPOCH[11] - STEP[120]
# Generator_loss:0.9957
# L1_loss:0.2016
# Discriminator_loss:0.7319
#
# EPOCH[11] - STEP[140]
# Generator_loss:2.3192
# L1_loss:0.1558
# Discriminator_loss:0.6413
#
# EPOCH[11] - STEP[160]
# Generator_loss:3.2233
# L1_loss:0.1606
# Discriminator_loss:0.8678
#
# EPOCH[11] - STEP[180]
# Generator_loss:2.6147
# L1_loss:0.1589
# Discriminator_loss:0.4534
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.2518
# L1_loss:0.1796
# Discriminator_loss:0.4737
#
# EPOCH[11] - STEP[220]
# Generator_loss:2.2674
# L1_loss:0.1767
# Discriminator_loss:0.4806
#
# EPOCH[11] - STEP[240]
# Generator_loss:1.6709
# L1_loss:0.1764
# Discriminator_loss:0.4683
#
# EPOCH[12] - STEP[20]
# Generator_loss:1.7035
# L1_loss:0.1572
# Discriminator_loss:0.7426
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.9568
# L1_loss:0.1367
# Discriminator_loss:1.0481
#
# EPOCH[12] - STEP[60]
# Generator_loss:2.2529
# L1_loss:0.2304
# Discriminator_loss:0.2786
#
# EPOCH[12] - STEP[80]
# Generator_loss:2.8196
# L1_loss:0.2176
# Discriminator_loss:0.6110
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.7177
# L1_loss:0.1846
# Discriminator_loss:0.6290
#
# EPOCH[12] - STEP[120]
# Generator_loss:2.2081
# L1_loss:0.1720
# Discriminator_loss:0.9737
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.7032
# L1_loss:0.1950
# Discriminator_loss:0.3295
#
# EPOCH[12] - STEP[160]
# Generator_loss:2.5482
# L1_loss:0.1868
# Discriminator_loss:0.2846
#
# EPOCH[12] - STEP[180]
# Generator_loss:2.0844
# L1_loss:0.1763
# Discriminator_loss:0.3369
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.5785
# L1_loss:0.1549
# Discriminator_loss:0.9061
#
# EPOCH[12] - STEP[220]
# Generator_loss:0.3860
# L1_loss:0.1747
# Discriminator_loss:1.5488
#
# EPOCH[12] - STEP[240]
# Generator_loss:3.7461
# L1_loss:0.1920
# Discriminator_loss:2.1803
#
# EPOCH[13] - STEP[20]
# Generator_loss:3.3835
# L1_loss:0.1884
# Discriminator_loss:0.8525
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.5778
# L1_loss:0.1898
# Discriminator_loss:0.4455
#
# EPOCH[13] - STEP[60]
# Generator_loss:1.6329
# L1_loss:0.1531
# Discriminator_loss:0.9064
#
# EPOCH[13] - STEP[80]
# Generator_loss:0.9147
# L1_loss:0.1636
# Discriminator_loss:0.7091
#
# EPOCH[13] - STEP[100]
# Generator_loss:1.0534
# L1_loss:0.1949
# Discriminator_loss:0.6608
#
# EPOCH[13] - STEP[120]
# Generator_loss:0.5620
# L1_loss:0.1784
# Discriminator_loss:1.1872
#
# EPOCH[13] - STEP[140]
# Generator_loss:2.0114
# L1_loss:0.1711
# Discriminator_loss:0.5259
#
# EPOCH[13] - STEP[160]
# Generator_loss:4.1941
# L1_loss:0.1899
# Discriminator_loss:2.3958
#
# EPOCH[13] - STEP[180]
# Generator_loss:0.8021
# L1_loss:0.1786
# Discriminator_loss:0.9693
#
# EPOCH[13] - STEP[200]
# Generator_loss:2.5469
# L1_loss:0.1625
# Discriminator_loss:0.5978
#
# EPOCH[13] - STEP[220]
# Generator_loss:1.9572
# L1_loss:0.1741
# Discriminator_loss:0.5998
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.2727
# L1_loss:0.2070
# Discriminator_loss:0.6551
#
# EPOCH[14] - STEP[20]
# Generator_loss:0.9010
# L1_loss:0.1647
# Discriminator_loss:1.2375
#
# EPOCH[14] - STEP[40]
# Generator_loss:1.2324
# L1_loss:0.1499
# Discriminator_loss:0.6413
#
# EPOCH[14] - STEP[60]
# Generator_loss:2.1892
# L1_loss:0.1533
# Discriminator_loss:0.4948
#
# EPOCH[14] - STEP[80]
# Generator_loss:0.5774
# L1_loss:0.1623
# Discriminator_loss:1.2484
#
# EPOCH[14] - STEP[100]
# Generator_loss:1.7560
# L1_loss:0.1745
# Discriminator_loss:0.2586
#
# EPOCH[14] - STEP[120]
# Generator_loss:1.5847
# L1_loss:0.1771
# Discriminator_loss:1.5607
#
# EPOCH[14] - STEP[140]
# Generator_loss:1.0741
# L1_loss:0.1706
# Discriminator_loss:0.6297
#
# EPOCH[14] - STEP[160]
# Generator_loss:1.1357
# L1_loss:0.1362
# Discriminator_loss:0.6444
#
# EPOCH[14] - STEP[180]
# Generator_loss:2.7140
# L1_loss:0.1911
# Discriminator_loss:0.2220
#
# EPOCH[14] - STEP[200]
# Generator_loss:3.6043
# L1_loss:0.1336
# Discriminator_loss:0.3313
#
# EPOCH[14] - STEP[220]
# Generator_loss:3.0599
# L1_loss:0.1540
# Discriminator_loss:2.8448
#
# EPOCH[14] - STEP[240]
# Generator_loss:0.8769
# L1_loss:0.1756
# Discriminator_loss:0.7789
#
# EPOCH[15] - STEP[20]
# Generator_loss:1.7252
# L1_loss:0.1522
# Discriminator_loss:0.3376
#
# EPOCH[15] - STEP[40]
# Generator_loss:4.1657
# L1_loss:0.1432
# Discriminator_loss:1.4680
#
# EPOCH[15] - STEP[60]
# Generator_loss:1.8571
# L1_loss:0.1631
# Discriminator_loss:0.5556
#
# EPOCH[15] - STEP[80]
# Generator_loss:2.4723
# L1_loss:0.1486
# Discriminator_loss:0.8284
#
# EPOCH[15] - STEP[100]
# Generator_loss:1.8470
# L1_loss:0.1905
# Discriminator_loss:0.3904
#
# EPOCH[15] - STEP[120]
# Generator_loss:1.1824
# L1_loss:0.1751
# Discriminator_loss:0.6767
#
# EPOCH[15] - STEP[140]
# Generator_loss:1.1129
# L1_loss:0.2016
# Discriminator_loss:0.6591
#
# EPOCH[15] - STEP[160]
# Generator_loss:2.1594
# L1_loss:0.1466
# Discriminator_loss:1.0850
#
# EPOCH[15] - STEP[180]
# Generator_loss:1.7009
# L1_loss:0.1840
# Discriminator_loss:0.3740
#
# EPOCH[15] - STEP[200]
# Generator_loss:2.1211
# L1_loss:0.1620
# Discriminator_loss:0.9517
#
# EPOCH[15] - STEP[220]
# Generator_loss:2.0606
# L1_loss:0.1698
# Discriminator_loss:1.0802
#
# EPOCH[15] - STEP[240]
# Generator_loss:3.4038
# L1_loss:0.1802
# Discriminator_loss:0.4145
#
# EPOCH[16] - STEP[20]
# Generator_loss:1.8739
# L1_loss:0.1514
# Discriminator_loss:0.9841
#
# EPOCH[16] - STEP[40]
# Generator_loss:2.2181
# L1_loss:0.2161
# Discriminator_loss:0.2387
#
# EPOCH[16] - STEP[60]
# Generator_loss:3.5243
# L1_loss:0.1493
# Discriminator_loss:1.2866
#
# EPOCH[16] - STEP[80]
# Generator_loss:1.5862
# L1_loss:0.1868
# Discriminator_loss:0.3261
#
# EPOCH[16] - STEP[100]
# Generator_loss:0.6256
# L1_loss:0.1661
# Discriminator_loss:1.0090
#
# EPOCH[16] - STEP[120]
# Generator_loss:1.8940
# L1_loss:0.1697
# Discriminator_loss:0.2557
#
# EPOCH[16] - STEP[140]
# Generator_loss:1.3597
# L1_loss:0.2087
# Discriminator_loss:1.3243
#
# EPOCH[16] - STEP[160]
# Generator_loss:3.8988
# L1_loss:0.1742
# Discriminator_loss:0.7878
#
# EPOCH[16] - STEP[180]
# Generator_loss:2.2685
# L1_loss:0.1491
# Discriminator_loss:0.6630
#
# EPOCH[16] - STEP[200]
# Generator_loss:2.6659
# L1_loss:0.1590
# Discriminator_loss:0.3529
#
# EPOCH[16] - STEP[220]
# Generator_loss:3.6418
# L1_loss:0.1473
# Discriminator_loss:1.6768
#
# EPOCH[16] - STEP[240]
# Generator_loss:2.5136
# L1_loss:0.1797
# Discriminator_loss:0.2285
#
# EPOCH[17] - STEP[20]
# Generator_loss:0.9872
# L1_loss:0.1330
# Discriminator_loss:0.9801
#
# EPOCH[17] - STEP[40]
# Generator_loss:1.6538
# L1_loss:0.1983
# Discriminator_loss:0.4120
#
# EPOCH[17] - STEP[60]
# Generator_loss:1.6882
# L1_loss:0.1668
# Discriminator_loss:0.3804
#
# EPOCH[17] - STEP[80]
# Generator_loss:2.5716
# L1_loss:0.1807
# Discriminator_loss:0.2846
#
# EPOCH[17] - STEP[100]
# Generator_loss:1.9971
# L1_loss:0.1692
# Discriminator_loss:0.4131
#
# EPOCH[17] - STEP[120]
# Generator_loss:1.1285
# L1_loss:0.1368
# Discriminator_loss:0.6950
#
# EPOCH[17] - STEP[140]
# Generator_loss:3.1300
# L1_loss:0.1637
# Discriminator_loss:0.8995
#
# EPOCH[17] - STEP[160]
# Generator_loss:2.9228
# L1_loss:0.1638
# Discriminator_loss:1.0792
#
# EPOCH[17] - STEP[180]
# Generator_loss:2.0381
# L1_loss:0.2037
# Discriminator_loss:0.2695
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.8352
# L1_loss:0.1680
# Discriminator_loss:0.2797
#
# EPOCH[17] - STEP[220]
# Generator_loss:2.6337
# L1_loss:0.1866
# Discriminator_loss:0.4257
#
# EPOCH[17] - STEP[240]
# Generator_loss:0.8780
# L1_loss:0.1994
# Discriminator_loss:0.8040
#
# EPOCH[18] - STEP[20]
# Generator_loss:2.1456
# L1_loss:0.1659
# Discriminator_loss:0.2178
#
# EPOCH[18] - STEP[40]
# Generator_loss:0.3879
# L1_loss:0.2037
# Discriminator_loss:1.3277
#
# EPOCH[18] - STEP[60]
# Generator_loss:2.1061
# L1_loss:0.1281
# Discriminator_loss:0.4630
#
# EPOCH[18] - STEP[80]
# Generator_loss:1.8352
# L1_loss:0.1723
# Discriminator_loss:0.5495
#
# EPOCH[18] - STEP[100]
# Generator_loss:3.8219
# L1_loss:0.1533
# Discriminator_loss:0.8259
#
# EPOCH[18] - STEP[120]
# Generator_loss:0.9405
# L1_loss:0.2034
# Discriminator_loss:0.7083
#
# EPOCH[18] - STEP[140]
# Generator_loss:1.4180
# L1_loss:0.1417
# Discriminator_loss:0.4958
#
# EPOCH[18] - STEP[160]
# Generator_loss:3.3595
# L1_loss:0.1560
# Discriminator_loss:1.1065
#
# EPOCH[18] - STEP[180]
# Generator_loss:0.7163
# L1_loss:0.1647
# Discriminator_loss:0.8659
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.8604
# L1_loss:0.1592
# Discriminator_loss:0.5962
#
# EPOCH[18] - STEP[220]
# Generator_loss:1.7594
# L1_loss:0.2137
# Discriminator_loss:0.3744
#
# EPOCH[18] - STEP[240]
# Generator_loss:3.7108
# L1_loss:0.1290
# Discriminator_loss:2.4705
#
# EPOCH[19] - STEP[20]
# Generator_loss:2.9875
# L1_loss:0.1507
# Discriminator_loss:1.0332
#
# EPOCH[19] - STEP[40]
# Generator_loss:0.3630
# L1_loss:0.1623
# Discriminator_loss:1.7266
#
# EPOCH[19] - STEP[60]
# Generator_loss:0.9115
# L1_loss:0.1692
# Discriminator_loss:0.8349
#
# EPOCH[19] - STEP[80]
# Generator_loss:2.2386
# L1_loss:0.1491
# Discriminator_loss:1.0096
#
# EPOCH[19] - STEP[100]
# Generator_loss:1.8984
# L1_loss:0.1333
# Discriminator_loss:0.9975
#
# EPOCH[19] - STEP[120]
# Generator_loss:0.7262
# L1_loss:0.1935
# Discriminator_loss:1.4021
#
# EPOCH[19] - STEP[140]
# Generator_loss:2.9157
# L1_loss:0.1785
# Discriminator_loss:0.6520
#
# EPOCH[19] - STEP[160]
# Generator_loss:2.3145
# L1_loss:0.1895
# Discriminator_loss:0.3313
#
# EPOCH[19] - STEP[180]
# Generator_loss:2.0547
# L1_loss:0.1595
# Discriminator_loss:0.6730
#
# EPOCH[19] - STEP[200]
# Generator_loss:2.5734
# L1_loss:0.1723
# Discriminator_loss:0.4195
#
# EPOCH[19] - STEP[220]
# Generator_loss:2.5365
# L1_loss:0.1596
# Discriminator_loss:0.3623
#
# EPOCH[19] - STEP[240]
# Generator_loss:1.7512
# L1_loss:0.2279
# Discriminator_loss:0.4473
#
# EPOCH[20] - STEP[20]
# Generator_loss:2.2992
# L1_loss:0.1561
# Discriminator_loss:0.3929
#
# EPOCH[20] - STEP[40]
# Generator_loss:0.8055
# L1_loss:0.2012
# Discriminator_loss:1.0574
#
# EPOCH[20] - STEP[60]
# Generator_loss:2.7864
# L1_loss:0.1575
# Discriminator_loss:0.6900
#
# EPOCH[20] - STEP[80]
# Generator_loss:1.9799
# L1_loss:0.1520
# Discriminator_loss:2.4808
#
# EPOCH[20] - STEP[100]
# Generator_loss:3.3142
# L1_loss:0.1407
# Discriminator_loss:2.0042
#
# EPOCH[20] - STEP[120]
# Generator_loss:1.8636
# L1_loss:0.1479
# Discriminator_loss:0.3910
#
# EPOCH[20] - STEP[140]
# Generator_loss:0.8548
# L1_loss:0.1434
# Discriminator_loss:1.3701
#
# EPOCH[20] - STEP[160]
# Generator_loss:1.9732
# L1_loss:0.1384
# Discriminator_loss:0.9556
#
# EPOCH[20] - STEP[180]
# Generator_loss:2.0329
# L1_loss:0.1525
# Discriminator_loss:0.3379
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.5961
# L1_loss:0.1610
# Discriminator_loss:0.4922
#
# EPOCH[20] - STEP[220]
# Generator_loss:2.3625
# L1_loss:0.1801
# Discriminator_loss:0.1528
#
# EPOCH[20] - STEP[240]
# Generator_loss:0.8937
# L1_loss:0.1834
# Discriminator_loss:0.7199
#
# EPOCH[21] - STEP[20]
# Generator_loss:0.9251
# L1_loss:0.1209
# Discriminator_loss:1.0789
#
# EPOCH[21] - STEP[40]
# Generator_loss:1.4055
# L1_loss:0.1540
# Discriminator_loss:0.4931
#
# EPOCH[21] - STEP[60]
# Generator_loss:1.6537
# L1_loss:0.1443
# Discriminator_loss:0.4732
#
# EPOCH[21] - STEP[80]
# Generator_loss:1.7327
# L1_loss:0.1505
# Discriminator_loss:0.6331
#
# EPOCH[21] - STEP[100]
# Generator_loss:1.4994
# L1_loss:0.1434
# Discriminator_loss:0.3972
#
# EPOCH[21] - STEP[120]
# Generator_loss:3.7843
# L1_loss:0.1543
# Discriminator_loss:0.3269
#
# EPOCH[21] - STEP[140]
# Generator_loss:1.9073
# L1_loss:0.1762
# Discriminator_loss:0.4340
#
# EPOCH[21] - STEP[160]
# Generator_loss:2.7879
# L1_loss:0.2062
# Discriminator_loss:0.6798
#
# EPOCH[21] - STEP[180]
# Generator_loss:1.7691
# L1_loss:0.1717
# Discriminator_loss:0.7599
#
# EPOCH[21] - STEP[200]
# Generator_loss:1.5480
# L1_loss:0.1670
# Discriminator_loss:0.4298
#
# EPOCH[21] - STEP[220]
# Generator_loss:1.1620
# L1_loss:0.1593
# Discriminator_loss:0.6066
#
# EPOCH[21] - STEP[240]
# Generator_loss:3.0848
# L1_loss:0.1557
# Discriminator_loss:0.2402
#
# EPOCH[22] - STEP[20]
# Generator_loss:3.0277
# L1_loss:0.1246
# Discriminator_loss:0.9795
#
# EPOCH[22] - STEP[40]
# Generator_loss:2.0808
# L1_loss:0.1446
# Discriminator_loss:0.5891
#
# EPOCH[22] - STEP[60]
# Generator_loss:1.6865
# L1_loss:0.1217
# Discriminator_loss:0.7572
#
# EPOCH[22] - STEP[80]
# Generator_loss:0.2265
# L1_loss:0.1620
# Discriminator_loss:2.6368
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.4107
# L1_loss:0.1455
# Discriminator_loss:0.4735
#
# EPOCH[22] - STEP[120]
# Generator_loss:1.4929
# L1_loss:0.1542
# Discriminator_loss:1.4247
#
# EPOCH[22] - STEP[140]
# Generator_loss:1.1170
# L1_loss:0.1632
# Discriminator_loss:0.7222
#
# EPOCH[22] - STEP[160]
# Generator_loss:0.3709
# L1_loss:0.1612
# Discriminator_loss:1.5795
#
# EPOCH[22] - STEP[180]
# Generator_loss:2.9729
# L1_loss:0.1753
# Discriminator_loss:0.6124
#
# EPOCH[22] - STEP[200]
# Generator_loss:2.4047
# L1_loss:0.1750
# Discriminator_loss:0.4842
#
# EPOCH[22] - STEP[220]
# Generator_loss:2.0636
# L1_loss:0.1959
# Discriminator_loss:0.3894
#
# EPOCH[22] - STEP[240]
# Generator_loss:2.9284
# L1_loss:0.1601
# Discriminator_loss:0.3887
#
# EPOCH[23] - STEP[20]
# Generator_loss:5.2485
# L1_loss:0.1614
# Discriminator_loss:0.3771
#
# EPOCH[23] - STEP[40]
# Generator_loss:1.1265
# L1_loss:0.1479
# Discriminator_loss:0.8671
#
# EPOCH[23] - STEP[60]
# Generator_loss:3.8809
# L1_loss:0.1492
# Discriminator_loss:0.7170
#
# EPOCH[23] - STEP[80]
# Generator_loss:1.7122
# L1_loss:0.2138
# Discriminator_loss:0.3476
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.5056
# L1_loss:0.1591
# Discriminator_loss:0.6504
#
# EPOCH[23] - STEP[120]
# Generator_loss:2.3061
# L1_loss:0.1560
# Discriminator_loss:0.2866
#
# EPOCH[23] - STEP[140]
# Generator_loss:2.1824
# L1_loss:0.1542
# Discriminator_loss:0.5287
#
# EPOCH[23] - STEP[160]
# Generator_loss:2.2032
# L1_loss:0.1498
# Discriminator_loss:0.2915
#
# EPOCH[23] - STEP[180]
# Generator_loss:1.6885
# L1_loss:0.1490
# Discriminator_loss:0.5515
#
# EPOCH[23] - STEP[200]
# Generator_loss:3.8545
# L1_loss:0.1872
# Discriminator_loss:0.6872
#
# EPOCH[23] - STEP[220]
# Generator_loss:1.5080
# L1_loss:0.1248
# Discriminator_loss:0.4827
#
# EPOCH[23] - STEP[240]
# Generator_loss:3.5835
# L1_loss:0.1778
# Discriminator_loss:0.0650
#
# EPOCH[24] - STEP[20]
# Generator_loss:1.9798
# L1_loss:0.1547
# Discriminator_loss:0.2702
#
# EPOCH[24] - STEP[40]
# Generator_loss:3.4642
# L1_loss:0.1897
# Discriminator_loss:0.8885
#
# EPOCH[24] - STEP[60]
# Generator_loss:1.8916
# L1_loss:0.1972
# Discriminator_loss:0.4098
#
# EPOCH[24] - STEP[80]
# Generator_loss:1.2116
# L1_loss:0.1971
# Discriminator_loss:0.4705
#
# EPOCH[24] - STEP[100]
# Generator_loss:2.7970
# L1_loss:0.1495
# Discriminator_loss:0.5726
#
# EPOCH[24] - STEP[120]
# Generator_loss:2.1998
# L1_loss:0.1440
# Discriminator_loss:0.1883
#
# EPOCH[24] - STEP[140]
# Generator_loss:4.6181
# L1_loss:0.1831
# Discriminator_loss:1.8881
#
# EPOCH[24] - STEP[160]
# Generator_loss:2.6429
# L1_loss:0.1786
# Discriminator_loss:0.4642
#
# EPOCH[24] - STEP[180]
# Generator_loss:1.9202
# L1_loss:0.1421
# Discriminator_loss:0.4223
#
# EPOCH[24] - STEP[200]
# Generator_loss:0.9427
# L1_loss:0.1357
# Discriminator_loss:0.9515
#
# EPOCH[24] - STEP[220]
# Generator_loss:1.0703
# L1_loss:0.1734
# Discriminator_loss:0.6784
#
# EPOCH[24] - STEP[240]
# Generator_loss:2.8494
# L1_loss:0.1324
# Discriminator_loss:0.4639
#
# EPOCH[25] - STEP[20]
# Generator_loss:3.4898
# L1_loss:0.1592
# Discriminator_loss:1.1982
#
# EPOCH[25] - STEP[40]
# Generator_loss:3.2442
# L1_loss:0.1550
# Discriminator_loss:0.1511
#
# EPOCH[25] - STEP[60]
# Generator_loss:2.4574
# L1_loss:0.1487
# Discriminator_loss:0.5643
#
# EPOCH[25] - STEP[80]
# Generator_loss:2.2854
# L1_loss:0.1521
# Discriminator_loss:0.6275
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.5254
# L1_loss:0.1348
# Discriminator_loss:0.8120
#
# EPOCH[25] - STEP[120]
# Generator_loss:1.6987
# L1_loss:0.2274
# Discriminator_loss:0.3616
#
# EPOCH[25] - STEP[140]
# Generator_loss:1.4018
# L1_loss:0.1731
# Discriminator_loss:0.6407
#
# EPOCH[25] - STEP[160]
# Generator_loss:1.2899
# L1_loss:0.1472
# Discriminator_loss:0.5360
#
# EPOCH[25] - STEP[180]
# Generator_loss:0.9980
# L1_loss:0.1464
# Discriminator_loss:0.7666
#
# EPOCH[25] - STEP[200]
# Generator_loss:1.6681
# L1_loss:0.1392
# Discriminator_loss:0.3618
#
# EPOCH[25] - STEP[220]
# Generator_loss:2.5840
# L1_loss:0.1719
# Discriminator_loss:0.2026
#
# EPOCH[25] - STEP[240]
# Generator_loss:1.9723
# L1_loss:0.1712
# Discriminator_loss:0.2656
#
# EPOCH[26] - STEP[20]
# Generator_loss:1.1314
# L1_loss:0.1742
# Discriminator_loss:0.7093
#
# EPOCH[26] - STEP[40]
# Generator_loss:1.1187
# L1_loss:0.1815
# Discriminator_loss:0.5506
#
# EPOCH[26] - STEP[60]
# Generator_loss:1.6192
# L1_loss:0.1707
# Discriminator_loss:0.6075
#
# EPOCH[26] - STEP[80]
# Generator_loss:1.8579
# L1_loss:0.1252
# Discriminator_loss:0.9443
#
# EPOCH[26] - STEP[100]
# Generator_loss:3.1317
# L1_loss:0.1424
# Discriminator_loss:1.8650
#
# EPOCH[26] - STEP[120]
# Generator_loss:2.0429
# L1_loss:0.1608
# Discriminator_loss:1.6843
#
# EPOCH[26] - STEP[140]
# Generator_loss:2.1409
# L1_loss:0.1727
# Discriminator_loss:0.2565
#
# EPOCH[26] - STEP[160]
# Generator_loss:3.5111
# L1_loss:0.1460
# Discriminator_loss:0.5539
#
# EPOCH[26] - STEP[180]
# Generator_loss:3.0336
# L1_loss:0.1495
# Discriminator_loss:0.2516
#
# EPOCH[26] - STEP[200]
# Generator_loss:4.2903
# L1_loss:0.1222
# Discriminator_loss:2.0126
#
# EPOCH[26] - STEP[220]
# Generator_loss:1.0809
# L1_loss:0.1657
# Discriminator_loss:0.5481
#
# EPOCH[26] - STEP[240]
# Generator_loss:2.5988
# L1_loss:0.2098
# Discriminator_loss:0.1711
#
# EPOCH[27] - STEP[20]
# Generator_loss:2.5841
# L1_loss:0.1372
# Discriminator_loss:1.1588
#
# EPOCH[27] - STEP[40]
# Generator_loss:2.8851
# L1_loss:0.1655
# Discriminator_loss:0.3867
#
# EPOCH[27] - STEP[60]
# Generator_loss:1.0917
# L1_loss:0.1563
# Discriminator_loss:0.5492
#
# EPOCH[27] - STEP[80]
# Generator_loss:1.4882
# L1_loss:0.1616
# Discriminator_loss:0.5614
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.6440
# L1_loss:0.1598
# Discriminator_loss:0.6778
#
# EPOCH[27] - STEP[120]
# Generator_loss:3.7057
# L1_loss:0.1625
# Discriminator_loss:0.8654
#
# EPOCH[27] - STEP[140]
# Generator_loss:2.3644
# L1_loss:0.1937
# Discriminator_loss:0.5963
#
# EPOCH[27] - STEP[160]
# Generator_loss:2.2155
# L1_loss:0.1846
# Discriminator_loss:1.1873
#
# EPOCH[27] - STEP[180]
# Generator_loss:2.9408
# L1_loss:0.1616
# Discriminator_loss:0.4679
#
# EPOCH[27] - STEP[200]
# Generator_loss:2.1177
# L1_loss:0.1973
# Discriminator_loss:0.2455
#
# EPOCH[27] - STEP[220]
# Generator_loss:3.5302
# L1_loss:0.1300
# Discriminator_loss:0.9411
#
# EPOCH[27] - STEP[240]
# Generator_loss:0.7083
# ...
# L1_loss:0.1228
# Discriminator_loss:0.1845
#
# EPOCH[92] - STEP[40]
# Generator_loss:2.2095
# L1_loss:0.1441
# Discriminator_loss:0.2565
#
# EPOCH[92] - STEP[60]
# Generator_loss:1.0930
# L1_loss:0.1014
# Discriminator_loss:0.7410
#
# EPOCH[92] - STEP[80]
# Generator_loss:2.4728
# L1_loss:0.1216
# Discriminator_loss:0.5355
#
# EPOCH[92] - STEP[100]
# Generator_loss:3.5507
# L1_loss:0.1479
# Discriminator_loss:0.3637
#
# EPOCH[92] - STEP[120]
# Generator_loss:1.3284
# L1_loss:0.1478
# Discriminator_loss:0.4669
#
# EPOCH[92] - STEP[140]
# Generator_loss:1.6800
# L1_loss:0.1211
# Discriminator_loss:0.3716
#
# EPOCH[92] - STEP[160]
# Generator_loss:2.5188
# L1_loss:0.1336
# Discriminator_loss:0.2532
#
# EPOCH[92] - STEP[180]
# Generator_loss:3.1284
# L1_loss:0.1150
# Discriminator_loss:0.3769
#
# EPOCH[92] - STEP[200]
# Generator_loss:2.7540
# L1_loss:0.1560
# Discriminator_loss:0.2681
#
# EPOCH[92] - STEP[220]
# Generator_loss:1.5837
# L1_loss:0.1280
# Discriminator_loss:0.3953
#
# EPOCH[92] - STEP[240]
# Generator_loss:3.0944
# L1_loss:0.1202
# Discriminator_loss:1.0374
#
# EPOCH[93] - STEP[20]
# Generator_loss:2.9376
# L1_loss:0.1301
# Discriminator_loss:0.6174
#
# EPOCH[93] - STEP[40]
# Generator_loss:6.0196
# L1_loss:0.1118
# Discriminator_loss:1.6383
#
# EPOCH[93] - STEP[60]
# Generator_loss:1.8338
# L1_loss:0.1390
# Discriminator_loss:0.3706
#
# EPOCH[93] - STEP[80]
# Generator_loss:3.7164
# L1_loss:0.1305
# Discriminator_loss:0.2568
#
# EPOCH[93] - STEP[100]
# Generator_loss:2.2908
# L1_loss:0.1370
# Discriminator_loss:0.2021
#
# EPOCH[93] - STEP[120]
# Generator_loss:0.7891
# L1_loss:0.1408
# Discriminator_loss:0.8951
#
# EPOCH[93] - STEP[140]
# Generator_loss:2.4682
# L1_loss:0.1445
# Discriminator_loss:0.1659
#
# EPOCH[93] - STEP[160]
# Generator_loss:1.7166
# L1_loss:0.1215
# Discriminator_loss:0.5564
#
# EPOCH[93] - STEP[180]
# Generator_loss:2.1853
# L1_loss:0.1373
# Discriminator_loss:0.2533
#
# EPOCH[93] - STEP[200]
# Generator_loss:2.8306
# L1_loss:0.1281
# Discriminator_loss:1.3401
#
# EPOCH[93] - STEP[220]
# Generator_loss:2.1902
# L1_loss:0.1103
# Discriminator_loss:0.5901
#
# EPOCH[93] - STEP[240]
# Generator_loss:3.3760
# L1_loss:0.1283
# Discriminator_loss:0.5019
#
# EPOCH[94] - STEP[20]
# Generator_loss:4.1547
# L1_loss:0.1830
# Discriminator_loss:0.0405
#
# EPOCH[94] - STEP[40]
# Generator_loss:0.8214
# L1_loss:0.1164
# Discriminator_loss:1.3027
#
# EPOCH[94] - STEP[60]
# Generator_loss:4.3197
# L1_loss:0.1235
# Discriminator_loss:0.0766
#
# EPOCH[94] - STEP[80]
# Generator_loss:3.1096
# L1_loss:0.1179
# Discriminator_loss:0.3059
#
# EPOCH[94] - STEP[100]
# Generator_loss:4.0067
# L1_loss:0.1618
# Discriminator_loss:0.0569
#
# EPOCH[94] - STEP[120]
# Generator_loss:5.3081
# L1_loss:0.1103
# Discriminator_loss:0.2021
#
# EPOCH[94] - STEP[140]
# Generator_loss:2.8855
# L1_loss:0.1279
# Discriminator_loss:0.1892
#
# EPOCH[94] - STEP[160]
# Generator_loss:5.4763
# L1_loss:0.1299
# Discriminator_loss:0.1532
#
# EPOCH[94] - STEP[180]
# Generator_loss:2.4788
# L1_loss:0.1463
# Discriminator_loss:0.2224
#
# EPOCH[94] - STEP[200]
# Generator_loss:4.7802
# L1_loss:0.1403
# Discriminator_loss:0.1870
#
# EPOCH[94] - STEP[220]
# Generator_loss:0.9671
# L1_loss:0.1090
# Discriminator_loss:0.9814
#
# EPOCH[94] - STEP[240]
# Generator_loss:5.2831
# L1_loss:0.1192
# Discriminator_loss:1.4078
#
# EPOCH[95] - STEP[20]
# Generator_loss:6.3330
# L1_loss:0.1292
# Discriminator_loss:1.8134
#
# EPOCH[95] - STEP[40]
# Generator_loss:3.9259
# L1_loss:0.1090
# Discriminator_loss:0.2055
#
# EPOCH[95] - STEP[60]
# Generator_loss:5.5543
# L1_loss:0.1857
# Discriminator_loss:0.2150
#
# EPOCH[95] - STEP[80]
# Generator_loss:5.6522
# L1_loss:0.1272
# Discriminator_loss:0.0315
#
# EPOCH[95] - STEP[100]
# Generator_loss:2.2517
# L1_loss:0.1472
# Discriminator_loss:0.2901
#
# EPOCH[95] - STEP[120]
# Generator_loss:2.2738
# L1_loss:0.1331
# Discriminator_loss:0.3302
#
# EPOCH[95] - STEP[140]
# Generator_loss:4.6816
# L1_loss:0.1139
# Discriminator_loss:0.2087
#
# EPOCH[95] - STEP[160]
# Generator_loss:4.9912
# L1_loss:0.1086
# Discriminator_loss:0.5750
#
# EPOCH[95] - STEP[180]
# Generator_loss:1.2647
# L1_loss:0.1491
# Discriminator_loss:0.4473
#
# EPOCH[95] - STEP[200]
# Generator_loss:0.3675
# L1_loss:0.1944
# Discriminator_loss:2.0030
#
# EPOCH[95] - STEP[220]
# Generator_loss:0.1050
# L1_loss:0.1277
# Discriminator_loss:3.0778
#
# EPOCH[95] - STEP[240]
# Generator_loss:3.3006
# L1_loss:0.1158
# Discriminator_loss:0.1120
#
# EPOCH[96] - STEP[20]
# Generator_loss:1.6234
# L1_loss:0.1365
# Discriminator_loss:0.6265
#
# EPOCH[96] - STEP[40]
# Generator_loss:2.3833
# L1_loss:0.1287
# Discriminator_loss:0.2741
#
# EPOCH[96] - STEP[60]
# Generator_loss:2.0805
# L1_loss:0.1291
# Discriminator_loss:0.3616
#
# EPOCH[96] - STEP[80]
# Generator_loss:2.8888
# L1_loss:0.1498
# Discriminator_loss:0.1982
#
# EPOCH[96] - STEP[100]
# Generator_loss:2.3282
# L1_loss:0.1345
# Discriminator_loss:0.1836
#
# EPOCH[96] - STEP[120]
# Generator_loss:1.7566
# L1_loss:0.1541
# Discriminator_loss:0.3312
#
# EPOCH[96] - STEP[140]
# Generator_loss:2.4733
# L1_loss:0.1413
# Discriminator_loss:0.2108
#
# EPOCH[96] - STEP[160]
# Generator_loss:3.2603
# L1_loss:0.1178
# Discriminator_loss:0.5169
#
# EPOCH[96] - STEP[180]
# Generator_loss:2.4801
# L1_loss:0.1451
# Discriminator_loss:0.1793
#
# EPOCH[96] - STEP[200]
# Generator_loss:2.6421
# L1_loss:0.1825
# Discriminator_loss:0.1540
#
# EPOCH[96] - STEP[220]
# Generator_loss:2.1618
# L1_loss:0.1652
# Discriminator_loss:0.2381
#
# EPOCH[96] - STEP[240]
# Generator_loss:2.4217
# L1_loss:0.1281
# Discriminator_loss:0.1810
#
# EPOCH[97] - STEP[20]
# Generator_loss:0.6134
# L1_loss:0.1355
# Discriminator_loss:1.8213
#
# EPOCH[97] - STEP[40]
# Generator_loss:2.6418
# L1_loss:0.1390
# Discriminator_loss:0.5063
#
# EPOCH[97] - STEP[60]
# Generator_loss:4.5297
# L1_loss:0.1137
# Discriminator_loss:0.9275
#
# EPOCH[97] - STEP[80]
# Generator_loss:1.3411
# L1_loss:0.1653
# Discriminator_loss:0.6499
#
# EPOCH[97] - STEP[100]
# Generator_loss:4.8374
# L1_loss:0.1351
# Discriminator_loss:0.0405
#
# EPOCH[97] - STEP[120]
# Generator_loss:3.4301
# L1_loss:0.1146
# Discriminator_loss:0.6493
#
# EPOCH[97] - STEP[140]
# Generator_loss:3.0660
# L1_loss:0.1530
# Discriminator_loss:0.1367
#
# EPOCH[97] - STEP[160]
# Generator_loss:5.7667
# L1_loss:0.1388
# Discriminator_loss:1.8771
#
# EPOCH[97] - STEP[180]
# Generator_loss:5.1997
# L1_loss:0.1262
# Discriminator_loss:0.1271
#
# EPOCH[97] - STEP[200]
# Generator_loss:1.6485
# L1_loss:0.1329
# Discriminator_loss:0.4452
#
# EPOCH[97] - STEP[220]
# Generator_loss:1.9829
# L1_loss:0.1092
# Discriminator_loss:0.3528
#
# EPOCH[97] - STEP[240]
# Generator_loss:1.6443
# L1_loss:0.1492
# Discriminator_loss:0.3760
#
# EPOCH[98] - STEP[20]
# Generator_loss:1.9110
# L1_loss:0.1115
# Discriminator_loss:0.3162
#
# EPOCH[98] - STEP[40]
# Generator_loss:5.3858
# L1_loss:0.1586
# Discriminator_loss:0.0337
#
# EPOCH[98] - STEP[60]
# Generator_loss:2.6547
# L1_loss:0.1118
# Discriminator_loss:1.4420
#
# EPOCH[98] - STEP[80]
# Generator_loss:1.6924
# L1_loss:0.1495
# Discriminator_loss:0.3883
#
# EPOCH[98] - STEP[100]
# Generator_loss:2.7167
# L1_loss:0.1592
# Discriminator_loss:0.2294
#
# EPOCH[98] - STEP[120]
# Generator_loss:1.6422
# L1_loss:0.1263
# Discriminator_loss:0.6708
#
# EPOCH[98] - STEP[140]
# Generator_loss:4.4840
# L1_loss:0.1498
# Discriminator_loss:0.4305
#
# EPOCH[98] - STEP[160]
# Generator_loss:0.7353
# L1_loss:0.1173
# Discriminator_loss:1.2059
#
# EPOCH[98] - STEP[180]
# Generator_loss:3.0038
# L1_loss:0.1090
# Discriminator_loss:0.4240
#
# EPOCH[98] - STEP[200]
# Generator_loss:2.9104
# L1_loss:0.1306
# Discriminator_loss:0.2103
#
# EPOCH[98] - STEP[220]
# Generator_loss:3.4897
# L1_loss:0.1058
# Discriminator_loss:0.3369
#
# EPOCH[98] - STEP[240]
# Generator_loss:1.4538
# L1_loss:0.1410
# Discriminator_loss:0.4953
#
# EPOCH[99] - STEP[20]
# Generator_loss:4.6816
# L1_loss:0.1471
# Discriminator_loss:0.0466
#
# EPOCH[99] - STEP[40]
# Generator_loss:3.3078
# L1_loss:0.1137
# Discriminator_loss:0.2791
#
# EPOCH[99] - STEP[60]
# Generator_loss:1.2129
# L1_loss:0.1181
# Discriminator_loss:1.3221
#
# EPOCH[99] - STEP[80]
# Generator_loss:4.3012
# L1_loss:0.1088
# Discriminator_loss:1.7262
#
# EPOCH[99] - STEP[100]
# Generator_loss:3.7207
# L1_loss:0.1169
# Discriminator_loss:0.0849
#
# EPOCH[99] - STEP[120]
# Generator_loss:3.8489
# L1_loss:0.1306
# Discriminator_loss:0.3906
#
# EPOCH[99] - STEP[140]
# Generator_loss:3.6122
# L1_loss:0.1076
# Discriminator_loss:0.6387
#
# EPOCH[99] - STEP[160]
# Generator_loss:3.3717
# L1_loss:0.1512
# Discriminator_loss:0.1232
#
# EPOCH[99] - STEP[180]
# Generator_loss:1.6266
# L1_loss:0.1197
# Discriminator_loss:1.1292
#
# EPOCH[99] - STEP[200]
# Generator_loss:2.9116
# L1_loss:0.1081
# Discriminator_loss:1.0618
#
# EPOCH[99] - STEP[220]
# Generator_loss:4.2835
# L1_loss:0.1509
# Discriminator_loss:0.0406
#
# EPOCH[99] - STEP[240]
# Generator_loss:4.7721
# L1_loss:0.1290
# Discriminator_loss:0.0435
#
# EPOCH[100] - STEP[20]
# Generator_loss:3.2617
# L1_loss:0.1103
# Discriminator_loss:0.7133
#
# EPOCH[100] - STEP[40]
# Generator_loss:1.5105
# L1_loss:0.1220
# Discriminator_loss:0.4514
#
# EPOCH[100] - STEP[60]
# Generator_loss:1.7203
# L1_loss:0.1364
# Discriminator_loss:0.3320
#
# EPOCH[100] - STEP[80]
# Generator_loss:1.1126
# L1_loss:0.1551
# Discriminator_loss:0.6503
#
# EPOCH[100] - STEP[100]
# Generator_loss:0.4206
# L1_loss:0.1188
# Discriminator_loss:1.4444
#
# EPOCH[100] - STEP[120]
# Generator_loss:1.7119
# L1_loss:0.1867
# Discriminator_loss:0.3993
#
# EPOCH[100] - STEP[140]
# Generator_loss:2.3230
# L1_loss:0.1100
# Discriminator_loss:0.2737
#
# EPOCH[100] - STEP[160]
# Generator_loss:5.5140
# L1_loss:0.1218
# Discriminator_loss:0.1133
#
# EPOCH[100] - STEP[180]
# Generator_loss:3.0214
# L1_loss:0.1345
# Discriminator_loss:0.1067
#
# EPOCH[100] - STEP[200]
# Generator_loss:2.8029
# L1_loss:0.1201
# Discriminator_loss:0.2080
#
# EPOCH[100] - STEP[220]
# Generator_loss:3.7355
# L1_loss:0.1338
# Discriminator_loss:0.1948
#
# EPOCH[100] - STEP[240]
# Generator_loss:1.8092
# L1_loss:0.1189
# Discriminator_loss:0.5903

# %%
#채색하기(시각화)
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, original = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))

plt.subplot(1,3,1); plt.imshow(denormalize(original)); plt.title('sketch', fontsize=20)
plt.subplot(1,3,2); plt.imshow(pred[0]); plt.title('generated photo', fontsize=20)
plt.subplot(1,3,3); plt.imshow(denormalize(sketch)); plt.title('original photo', fontsize=20)
# Out:
# Text(0.5, 1.0, 'original photo')

# %% [markdown]
# 이미지에 테스트 과정을 거친 후 결과를 **스케치, 생성된 사진, 실제 사진** 순서로 나란히 시각화했다.

# %% [markdown]
# # 회고
# ***
# 모델학습을 20번 했을때와 100번 했을때 품질 향상이 생각보다 좋지 않은 것 같다. 노이즈가 많이 낀 이미지이다.
# pix2pix모델 구현하는 것과 비슷한 것 같아서 많이 어려운 건 아니였지만 Generator이론을 이해하는 것이 어려웠었다.
# 그래도 GAN이란 모델을 실습하면서 재미를 느꼈다.
